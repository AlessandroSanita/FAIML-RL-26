# %% [markdown]
# **Set-up dell'ambiente**

# %%
import subprocess
subprocess.run(["pip", "install", "-q", "--force-reinstall", "opencv-python-headless==4.9.0.80"])
# Out:
# CompletedProcess(args=['pip', 'install', '-q', '--force-reinstall', 'opencv-python-headless==4.9.0.80'], returncode=0)

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install -r /content/drive/MyDrive/FAIML-RL-26/requirements.txt -q

# %cd /content/drive/MyDrive/FAIML-RL-26/part2/panda-gym
# !pip install -e .
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/FAIML-RL-26/part2/panda-gym
# Obtaining file:///content/drive/MyDrive/FAIML-RL-26/part2/panda-gym
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gymnasium>=0.26 in /usr/local/lib/python3.12/dist-packages (from panda_gym==3.0.8) (1.2.3)
# Requirement already satisfied: pybullet in /usr/local/lib/python3.12/dist-packages (from panda_gym==3.0.8) (3.2.7)
# Collecting numpy<2 (from panda_gym==3.0.8)
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from panda_gym==3.0.8) (1.16.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium>=0.26->panda_gym==3.0.8) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium>=0.26->panda_gym==3.0.8) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium>=0.26->panda_gym==3.0.8) (0.0.4)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# Installing collected packages: numpy, panda_gym
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.6
#     Uninstalling numpy-2.4.6:
#       Successfully uninstalled numpy-2.4.6
#   Attempting uninstall: panda_gym
#     Found existing installation: panda_gym 3.0.8
#     Uninstalling panda_gym-3.0.8:
#       Successfully uninstalled panda_gym-3.0.8
#   Running setup.py develop for panda_gym
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4 panda_gym-3.0.8

# %% [markdown]
# **Import necessari**

# %%
#import argparse
from collections import deque

import gymnasium as gym
import numpy as np
import panda_gym  # type: ignore[import-not-found]
#from stable_baselines3 import DDPG
#from rand_wrapper import RandomizationWrapper
from stable_baselines3 import SAC, PPO
from stable_baselines3.common.callbacks import CheckpointCallback, EvalCallback, CallbackList
import matplotlib.pyplot as plt
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# **Parse_args non serve dato che siamo su notebook colab**

# %%
#def parse_args() -> argparse.Namespace:
#    parser = argparse.ArgumentParser(description="Train SAC on PandaPush-v3")
#    parser.add_argument(
#        "--sampling-strategy",
#        type=str,
#        default="none",
#        choices=["none", "udr", "adr"],
#        help="Sampling strategy for the object mass",
#    )
#    parser.add_argument(
#        "--env-type",
#        type=str,
#        default="source",
#        choices=["source", "target"],
#        help="PandaPush environment type",
#    )
#    parser.add_argument(
#        "--timesteps",
#        type=int,
#        default=500_000,
#        help="Number of training timesteps",
#    )
#    return parser.parse_args()

# %% [markdown]
# **Main SAC**

# %%
def main() -> None:
    #args = parse_args()

    env = gym.make(
        "PandaPush-v3",
        render_mode="rgb_array",
        type="source",
        reward_type="dense",
    )

    # Ambiente di valutazione SEPARATO (obbligatorio per EvalCallback)
    eval_env = gym.make(
        "PandaPush-v3",
        render_mode="rgb_array",
        type="source",
        reward_type="dense",
    )

    checkpoint_callback = CheckpointCallback(
      save_freq=50000,
      save_path="/content/drive/MyDrive/FAIML-RL-26/checkpoints/",
      name_prefix="sac_source",
      save_replay_buffer=True,
    )

    # Valuta ogni 50k timesteps e salva il modello migliore
    eval_callback = EvalCallback(
        eval_env,
        best_model_save_path=f"/content/drive/MyDrive/FAIML-RL-26/evalcallback/sac_source/",
        log_path=f"/content/drive/MyDrive/FAIML-RL-26/evalcallback/sac_source/",
        eval_freq=50000,
        n_eval_episodes=20,
        deterministic=True,
        verbose=1,
    )

    #TODO: add randomization wrapper here
    #TODO: create model and train it
    model = SAC("MultiInputPolicy", env, verbose=1, seed=42, device="cuda")
    model.learn(total_timesteps=500000, callback=CallbackList([checkpoint_callback, eval_callback]))
    save_name = f"sac_push_none_source_500000"
    # TODO: model.save(save_name)
    model.save(f"/content/drive/MyDrive/FAIML-RL-26/results/sac_source/{save_name}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Created object with mass: 1.0
# Created object with mass: 1.0
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 37.8     |
# |    ep_rew_mean     | -3.95    |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 68       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 151      |
# | train/             |          |
# |    actor_loss      | -3.55    |
# |    critic_loss     | 0.509    |
# |    ent_coef        | 0.985    |
# |    ent_coef_loss   | -0.0745  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 50       |
# ---------------------------------
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Output streaming troncato alle ultime 5000 righe.
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 62       |
# |    time_elapsed    | 84       |
# |    total_timesteps | 5277     |
# | train/             |          |
# |    actor_loss      | -17.8    |
# |    critic_loss     | 2.14     |
# |    ent_coef        | 0.215    |
# |    ent_coef_loss   | -7.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5176     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40       |
# |    ep_rew_mean     | -4.26    |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 62       |
# |    time_elapsed    | 86       |
# |    total_timesteps | 5428     |
# | train/             |          |
# |    actor_loss      | -17.9    |
# |    critic_loss     | 0.292    |
# |    ent_coef        | 0.205    |
# |    ent_coef_loss   | -7.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5327     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.5     |
# |    ep_rew_mean     | -4.23    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 62       |
# |    time_elapsed    | 90       |
# |    total_timesteps | 5628     |
# | train/             |          |
# |    actor_loss      | -18      |
# |    critic_loss     | 0.756    |
# |    ent_coef        | 0.194    |
# |    ent_coef_loss   | -7.62    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5527     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41       |
# |    ep_rew_mean     | -4.32    |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 62       |
# |    time_elapsed    | 93       |
# |    total_timesteps | 5828     |
# | train/             |          |
# |    actor_loss      | -17.8    |
# |    critic_loss     | 0.948    |
# |    ent_coef        | 0.183    |
# |    ent_coef_loss   | -7.82    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5727     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.5     |
# |    ep_rew_mean     | -4.32    |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 62       |
# |    time_elapsed    | 96       |
# |    total_timesteps | 6028     |
# | train/             |          |
# |    actor_loss      | -17.9    |
# |    critic_loss     | 2.12     |
# |    ent_coef        | 0.173    |
# |    ent_coef_loss   | -7.87    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5927     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.5     |
# |    ep_rew_mean     | -4.47    |
# |    success_rate    | 0.16     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 62       |
# |    time_elapsed    | 99       |
# |    total_timesteps | 6228     |
# | train/             |          |
# |    actor_loss      | -17.9    |
# |    critic_loss     | 1.68     |
# |    ent_coef        | 0.163    |
# |    ent_coef_loss   | -8.05    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6127     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.5     |
# |    ep_rew_mean     | -4.47    |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 62       |
# |    time_elapsed    | 100      |
# |    total_timesteps | 6330     |
# | train/             |          |
# |    actor_loss      | -17.7    |
# |    critic_loss     | 0.953    |
# |    ent_coef        | 0.158    |
# |    ent_coef_loss   | -8.12    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6229     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.5     |
# |    ep_rew_mean     | -4.39    |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 62       |
# |    time_elapsed    | 103      |
# |    total_timesteps | 6481     |
# | train/             |          |
# |    actor_loss      | -17.8    |
# |    critic_loss     | 1.1      |
# |    ent_coef        | 0.151    |
# |    ent_coef_loss   | -8.51    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6380     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41       |
# |    ep_rew_mean     | -4.38    |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 62       |
# |    time_elapsed    | 105      |
# |    total_timesteps | 6632     |
# | train/             |          |
# |    actor_loss      | -17.8    |
# |    critic_loss     | 0.823    |
# |    ent_coef        | 0.145    |
# |    ent_coef_loss   | -8.28    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6531     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.6     |
# |    ep_rew_mean     | -4.14    |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 62       |
# |    time_elapsed    | 106      |
# |    total_timesteps | 6685     |
# | train/             |          |
# |    actor_loss      | -17.6    |
# |    critic_loss     | 2.58     |
# |    ent_coef        | 0.143    |
# |    ent_coef_loss   | -8.45    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6584     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40       |
# |    ep_rew_mean     | -4.51    |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 62       |
# |    time_elapsed    | 109      |
# |    total_timesteps | 6885     |
# | train/             |          |
# |    actor_loss      | -17.6    |
# |    critic_loss     | 0.992    |
# |    ent_coef        | 0.135    |
# |    ent_coef_loss   | -8.67    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6784     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.5     |
# |    ep_rew_mean     | -5.02    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 62       |
# |    time_elapsed    | 112      |
# |    total_timesteps | 7085     |
# | train/             |          |
# |    actor_loss      | -17.5    |
# |    critic_loss     | 0.462    |
# |    ent_coef        | 0.127    |
# |    ent_coef_loss   | -9.12    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6984     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40       |
# |    ep_rew_mean     | -4.96    |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 62       |
# |    time_elapsed    | 115      |
# |    total_timesteps | 7236     |
# | train/             |          |
# |    actor_loss      | -17.2    |
# |    critic_loss     | 1.14     |
# |    ent_coef        | 0.122    |
# |    ent_coef_loss   | -9.17    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7135     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41       |
# |    ep_rew_mean     | -5.07    |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 62       |
# |    time_elapsed    | 117      |
# |    total_timesteps | 7387     |
# | train/             |          |
# |    actor_loss      | -17.1    |
# |    critic_loss     | 2.12     |
# |    ent_coef        | 0.116    |
# |    ent_coef_loss   | -9.39    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7286     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.7     |
# |    ep_rew_mean     | -5.12    |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 62       |
# |    time_elapsed    | 120      |
# |    total_timesteps | 7538     |
# | train/             |          |
# |    actor_loss      | -17.1    |
# |    critic_loss     | 1.59     |
# |    ent_coef        | 0.111    |
# |    ent_coef_loss   | -9.71    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7437     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.7     |
# |    ep_rew_mean     | -5.22    |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 62       |
# |    time_elapsed    | 122      |
# |    total_timesteps | 7689     |
# | train/             |          |
# |    actor_loss      | -16.7    |
# |    critic_loss     | 0.944    |
# |    ent_coef        | 0.107    |
# |    ent_coef_loss   | -9.43    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7588     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.7     |
# |    ep_rew_mean     | -5.33    |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 62       |
# |    time_elapsed    | 124      |
# |    total_timesteps | 7840     |
# | train/             |          |
# |    actor_loss      | -16.8    |
# |    critic_loss     | 1.68     |
# |    ent_coef        | 0.102    |
# |    ent_coef_loss   | -9.88    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7739     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.2     |
# |    ep_rew_mean     | -5.25    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 62       |
# |    time_elapsed    | 127      |
# |    total_timesteps | 7991     |
# | train/             |          |
# |    actor_loss      | -16.6    |
# |    critic_loss     | 2.98     |
# |    ent_coef        | 0.0977   |
# |    ent_coef_loss   | -9.88    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7890     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.2     |
# |    ep_rew_mean     | -5.22    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 62       |
# |    time_elapsed    | 129      |
# |    total_timesteps | 8142     |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 0.807    |
# |    ent_coef        | 0.0935   |
# |    ent_coef_loss   | -9.92    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8041     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.2     |
# |    ep_rew_mean     | -5.35    |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 62       |
# |    time_elapsed    | 133      |
# |    total_timesteps | 8342     |
# | train/             |          |
# |    actor_loss      | -16.5    |
# |    critic_loss     | 0.816    |
# |    ent_coef        | 0.0882   |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8241     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.7     |
# |    ep_rew_mean     | -5.42    |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 62       |
# |    time_elapsed    | 136      |
# |    total_timesteps | 8542     |
# | train/             |          |
# |    actor_loss      | -16.2    |
# |    critic_loss     | 0.514    |
# |    ent_coef        | 0.0833   |
# |    ent_coef_loss   | -10.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8441     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.7     |
# |    ep_rew_mean     | -5.41    |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 62       |
# |    time_elapsed    | 139      |
# |    total_timesteps | 8742     |
# | train/             |          |
# |    actor_loss      | -16.1    |
# |    critic_loss     | 0.775    |
# |    ent_coef        | 0.0786   |
# |    ent_coef_loss   | -10.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8641     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.7     |
# |    ep_rew_mean     | -5.4     |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 62       |
# |    time_elapsed    | 141      |
# |    total_timesteps | 8893     |
# | train/             |          |
# |    actor_loss      | -16      |
# |    critic_loss     | 0.383    |
# |    ent_coef        | 0.0753   |
# |    ent_coef_loss   | -10.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8792     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.7     |
# |    ep_rew_mean     | -5.32    |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 62       |
# |    time_elapsed    | 144      |
# |    total_timesteps | 9093     |
# | train/             |          |
# |    actor_loss      | -15.9    |
# |    critic_loss     | 0.363    |
# |    ent_coef        | 0.0711   |
# |    ent_coef_loss   | -11.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8992     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.2     |
# |    ep_rew_mean     | -5.36    |
# |    success_rate    | 0.16     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 62       |
# |    time_elapsed    | 148      |
# |    total_timesteps | 9293     |
# | train/             |          |
# |    actor_loss      | -15.4    |
# |    critic_loss     | 0.213    |
# |    ent_coef        | 0.0671   |
# |    ent_coef_loss   | -11      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9192     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.7     |
# |    ep_rew_mean     | -5.33    |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 62       |
# |    time_elapsed    | 150      |
# |    total_timesteps | 9444     |
# | train/             |          |
# |    actor_loss      | -15.1    |
# |    critic_loss     | 0.763    |
# |    ent_coef        | 0.0643   |
# |    ent_coef_loss   | -10.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9343     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.2     |
# |    ep_rew_mean     | -5.33    |
# |    success_rate    | 0.16     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 62       |
# |    time_elapsed    | 153      |
# |    total_timesteps | 9644     |
# | train/             |          |
# |    actor_loss      | -15.2    |
# |    critic_loss     | 0.683    |
# |    ent_coef        | 0.0608   |
# |    ent_coef_loss   | -10.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9543     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.7     |
# |    ep_rew_mean     | -5.26    |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 62       |
# |    time_elapsed    | 155      |
# |    total_timesteps | 9795     |
# | train/             |          |
# |    actor_loss      | -14.6    |
# |    critic_loss     | 0.78     |
# |    ent_coef        | 0.0583   |
# |    ent_coef_loss   | -10.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9694     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.7     |
# |    ep_rew_mean     | -5.17    |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 62       |
# |    time_elapsed    | 157      |
# |    total_timesteps | 9897     |
# | train/             |          |
# |    actor_loss      | -15      |
# |    critic_loss     | 0.201    |
# |    ent_coef        | 0.0566   |
# |    ent_coef_loss   | -11.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9796     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.2     |
# |    ep_rew_mean     | -5.09    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 62       |
# |    time_elapsed    | 160      |
# |    total_timesteps | 10048    |
# | train/             |          |
# |    actor_loss      | -14.9    |
# |    critic_loss     | 0.513    |
# |    ent_coef        | 0.0542   |
# |    ent_coef_loss   | -11.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9947     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.2     |
# |    ep_rew_mean     | -4.95    |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 62       |
# |    time_elapsed    | 161      |
# |    total_timesteps | 10150    |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 0.974    |
# |    ent_coef        | 0.0527   |
# |    ent_coef_loss   | -11.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10049    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.7     |
# |    ep_rew_mean     | -4.95    |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 62       |
# |    time_elapsed    | 164      |
# |    total_timesteps | 10301    |
# | train/             |          |
# |    actor_loss      | -14.5    |
# |    critic_loss     | 1.48     |
# |    ent_coef        | 0.0505   |
# |    ent_coef_loss   | -10.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10200    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.7     |
# |    ep_rew_mean     | -5.12    |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 62       |
# |    time_elapsed    | 166      |
# |    total_timesteps | 10452    |
# | train/             |          |
# |    actor_loss      | -14.2    |
# |    critic_loss     | 1.18     |
# |    ent_coef        | 0.0484   |
# |    ent_coef_loss   | -11.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10351    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.2     |
# |    ep_rew_mean     | -5.12    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 62       |
# |    time_elapsed    | 169      |
# |    total_timesteps | 10652    |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 1.29     |
# |    ent_coef        | 0.0457   |
# |    ent_coef_loss   | -10.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10551    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.7     |
# |    ep_rew_mean     | -5.24    |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 62       |
# |    time_elapsed    | 172      |
# |    total_timesteps | 10852    |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 0.372    |
# |    ent_coef        | 0.0433   |
# |    ent_coef_loss   | -11.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10751    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.7     |
# |    ep_rew_mean     | -4.92    |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 62       |
# |    time_elapsed    | 176      |
# |    total_timesteps | 11052    |
# | train/             |          |
# |    actor_loss      | -13.6    |
# |    critic_loss     | 0.32     |
# |    ent_coef        | 0.0409   |
# |    ent_coef_loss   | -11.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10951    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.7     |
# |    ep_rew_mean     | -4.41    |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 62       |
# |    time_elapsed    | 179      |
# |    total_timesteps | 11252    |
# | train/             |          |
# |    actor_loss      | -13.4    |
# |    critic_loss     | 0.11     |
# |    ent_coef        | 0.0387   |
# |    ent_coef_loss   | -10.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11151    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.2     |
# |    ep_rew_mean     | -4.37    |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 62       |
# |    time_elapsed    | 180      |
# |    total_timesteps | 11354    |
# | train/             |          |
# |    actor_loss      | -13.3    |
# |    critic_loss     | 0.821    |
# |    ent_coef        | 0.0377   |
# |    ent_coef_loss   | -11.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11253    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.2     |
# |    ep_rew_mean     | -4.37    |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 62       |
# |    time_elapsed    | 182      |
# |    total_timesteps | 11505    |
# | train/             |          |
# |    actor_loss      | -13.2    |
# |    critic_loss     | 0.295    |
# |    ent_coef        | 0.0362   |
# |    ent_coef_loss   | -10.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11404    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.7     |
# |    ep_rew_mean     | -4.25    |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 62       |
# |    time_elapsed    | 184      |
# |    total_timesteps | 11607    |
# | train/             |          |
# |    actor_loss      | -12.8    |
# |    critic_loss     | 0.391    |
# |    ent_coef        | 0.0352   |
# |    ent_coef_loss   | -9.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11506    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.2     |
# |    ep_rew_mean     | -4.17    |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 62       |
# |    time_elapsed    | 188      |
# |    total_timesteps | 11807    |
# | train/             |          |
# |    actor_loss      | -13      |
# |    critic_loss     | 1.23     |
# |    ent_coef        | 0.0333   |
# |    ent_coef_loss   | -10.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11706    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.2     |
# |    ep_rew_mean     | -3.96    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 62       |
# |    time_elapsed    | 189      |
# |    total_timesteps | 11860    |
# | train/             |          |
# |    actor_loss      | -12.9    |
# |    critic_loss     | 0.408    |
# |    ent_coef        | 0.0328   |
# |    ent_coef_loss   | -11.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11759    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.7     |
# |    ep_rew_mean     | -3.98    |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 62       |
# |    time_elapsed    | 191      |
# |    total_timesteps | 12060    |
# | train/             |          |
# |    actor_loss      | -12.7    |
# |    critic_loss     | 0.564    |
# |    ent_coef        | 0.0311   |
# |    ent_coef_loss   | -11.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11959    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.7     |
# |    ep_rew_mean     | -3.96    |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 62       |
# |    time_elapsed    | 194      |
# |    total_timesteps | 12211    |
# | train/             |          |
# |    actor_loss      | -12.6    |
# |    critic_loss     | 0.247    |
# |    ent_coef        | 0.0298   |
# |    ent_coef_loss   | -10.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12110    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.2     |
# |    ep_rew_mean     | -3.92    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 63       |
# |    time_elapsed    | 196      |
# |    total_timesteps | 12362    |
# | train/             |          |
# |    actor_loss      | -12.4    |
# |    critic_loss     | 0.229    |
# |    ent_coef        | 0.0286   |
# |    ent_coef_loss   | -10.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12261    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.7     |
# |    ep_rew_mean     | -3.84    |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 63       |
# |    time_elapsed    | 198      |
# |    total_timesteps | 12513    |
# | train/             |          |
# |    actor_loss      | -12.2    |
# |    critic_loss     | 0.436    |
# |    ent_coef        | 0.0275   |
# |    ent_coef_loss   | -10.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12412    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.7     |
# |    ep_rew_mean     | -3.89    |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 62       |
# |    time_elapsed    | 202      |
# |    total_timesteps | 12713    |
# | train/             |          |
# |    actor_loss      | -11.8    |
# |    critic_loss     | 0.401    |
# |    ent_coef        | 0.0261   |
# |    ent_coef_loss   | -11.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12612    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.7     |
# |    ep_rew_mean     | -3.89    |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 62       |
# |    time_elapsed    | 204      |
# |    total_timesteps | 12864    |
# | train/             |          |
# |    actor_loss      | -11.7    |
# |    critic_loss     | 0.309    |
# |    ent_coef        | 0.0251   |
# |    ent_coef_loss   | -10.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12763    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.2     |
# |    ep_rew_mean     | -3.84    |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 63       |
# |    time_elapsed    | 206      |
# |    total_timesteps | 13015    |
# | train/             |          |
# |    actor_loss      | -11.7    |
# |    critic_loss     | 0.262    |
# |    ent_coef        | 0.0241   |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12914    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.7     |
# |    ep_rew_mean     | -3.77    |
# |    success_rate    | 0.23     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 63       |
# |    time_elapsed    | 208      |
# |    total_timesteps | 13166    |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 0.199    |
# |    ent_coef        | 0.0231   |
# |    ent_coef_loss   | -9.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13065    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.2     |
# |    ep_rew_mean     | -3.79    |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 63       |
# |    time_elapsed    | 211      |
# |    total_timesteps | 13366    |
# | train/             |          |
# |    actor_loss      | -11.3    |
# |    critic_loss     | 0.297    |
# |    ent_coef        | 0.0219   |
# |    ent_coef_loss   | -9.65    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13265    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.2     |
# |    ep_rew_mean     | -3.84    |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 63       |
# |    time_elapsed    | 215      |
# |    total_timesteps | 13566    |
# | train/             |          |
# |    actor_loss      | -11.4    |
# |    critic_loss     | 0.298    |
# |    ent_coef        | 0.0207   |
# |    ent_coef_loss   | -11.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13465    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.7     |
# |    ep_rew_mean     | -3.81    |
# |    success_rate    | 0.23     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 63       |
# |    time_elapsed    | 216      |
# |    total_timesteps | 13668    |
# | train/             |          |
# |    actor_loss      | -11      |
# |    critic_loss     | 0.338    |
# |    ent_coef        | 0.0201   |
# |    ent_coef_loss   | -9.69    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13567    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.7     |
# |    ep_rew_mean     | -3.79    |
# |    success_rate    | 0.23     |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 63       |
# |    time_elapsed    | 218      |
# |    total_timesteps | 13770    |
# | train/             |          |
# |    actor_loss      | -11      |
# |    critic_loss     | 0.422    |
# |    ent_coef        | 0.0196   |
# |    ent_coef_loss   | -11.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13669    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.2     |
# |    ep_rew_mean     | -3.74    |
# |    success_rate    | 0.24     |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 63       |
# |    time_elapsed    | 219      |
# |    total_timesteps | 13872    |
# | train/             |          |
# |    actor_loss      | -10.8    |
# |    critic_loss     | 0.293    |
# |    ent_coef        | 0.0191   |
# |    ent_coef_loss   | -11.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13771    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.2     |
# |    ep_rew_mean     | -3.78    |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 63       |
# |    time_elapsed    | 222      |
# |    total_timesteps | 14072    |
# | train/             |          |
# |    actor_loss      | -11      |
# |    critic_loss     | 0.105    |
# |    ent_coef        | 0.0181   |
# |    ent_coef_loss   | -8.84    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13971    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.7     |
# |    ep_rew_mean     | -3.81    |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 63       |
# |    time_elapsed    | 225      |
# |    total_timesteps | 14272    |
# | train/             |          |
# |    actor_loss      | -10.5    |
# |    critic_loss     | 0.103    |
# |    ent_coef        | 0.0171   |
# |    ent_coef_loss   | -9.25    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14171    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.2     |
# |    ep_rew_mean     | -3.63    |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 63       |
# |    time_elapsed    | 227      |
# |    total_timesteps | 14374    |
# | train/             |          |
# |    actor_loss      | -10.5    |
# |    critic_loss     | 0.127    |
# |    ent_coef        | 0.0167   |
# |    ent_coef_loss   | -9.88    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14273    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.2     |
# |    ep_rew_mean     | -3.63    |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 63       |
# |    time_elapsed    | 230      |
# |    total_timesteps | 14574    |
# | train/             |          |
# |    actor_loss      | -10.4    |
# |    critic_loss     | 0.0681   |
# |    ent_coef        | 0.0158   |
# |    ent_coef_loss   | -10.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14473    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.2     |
# |    ep_rew_mean     | -3.6     |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 63       |
# |    time_elapsed    | 233      |
# |    total_timesteps | 14774    |
# | train/             |          |
# |    actor_loss      | -10.3    |
# |    critic_loss     | 0.303    |
# |    ent_coef        | 0.015    |
# |    ent_coef_loss   | -11      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14673    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.2     |
# |    ep_rew_mean     | -3.6     |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 63       |
# |    time_elapsed    | 236      |
# |    total_timesteps | 14974    |
# | train/             |          |
# |    actor_loss      | -10      |
# |    critic_loss     | 0.145    |
# |    ent_coef        | 0.0143   |
# |    ent_coef_loss   | -10.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14873    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.7     |
# |    ep_rew_mean     | -3.57    |
# |    success_rate    | 0.23     |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 63       |
# |    time_elapsed    | 238      |
# |    total_timesteps | 15125    |
# | train/             |          |
# |    actor_loss      | -10.1    |
# |    critic_loss     | 0.108    |
# |    ent_coef        | 0.0137   |
# |    ent_coef_loss   | -10.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15024    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.7     |
# |    ep_rew_mean     | -3.67    |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 63       |
# |    time_elapsed    | 242      |
# |    total_timesteps | 15325    |
# | train/             |          |
# |    actor_loss      | -9.67    |
# |    critic_loss     | 0.0681   |
# |    ent_coef        | 0.013    |
# |    ent_coef_loss   | -9.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15224    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.2     |
# |    ep_rew_mean     | -3.67    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 63       |
# |    time_elapsed    | 245      |
# |    total_timesteps | 15525    |
# | train/             |          |
# |    actor_loss      | -9.75    |
# |    critic_loss     | 0.0916   |
# |    ent_coef        | 0.0123   |
# |    ent_coef_loss   | -8.81    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15424    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.2     |
# |    ep_rew_mean     | -3.85    |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 63       |
# |    time_elapsed    | 248      |
# |    total_timesteps | 15725    |
# | train/             |          |
# |    actor_loss      | -9.52    |
# |    critic_loss     | 0.174    |
# |    ent_coef        | 0.0117   |
# |    ent_coef_loss   | -8.22    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15624    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.2     |
# |    ep_rew_mean     | -3.8     |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 63       |
# |    time_elapsed    | 251      |
# |    total_timesteps | 15925    |
# | train/             |          |
# |    actor_loss      | -9.22    |
# |    critic_loss     | 0.0444   |
# |    ent_coef        | 0.0111   |
# |    ent_coef_loss   | -9.47    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15824    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.2     |
# |    ep_rew_mean     | -3.88    |
# |    success_rate    | 0.16     |
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 63       |
# |    time_elapsed    | 253      |
# |    total_timesteps | 16076    |
# | train/             |          |
# |    actor_loss      | -9.14    |
# |    critic_loss     | 0.0415   |
# |    ent_coef        | 0.0107   |
# |    ent_coef_loss   | -8.46    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15975    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.2     |
# |    ep_rew_mean     | -3.84    |
# |    success_rate    | 0.16     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 63       |
# |    time_elapsed    | 256      |
# |    total_timesteps | 16276    |
# | train/             |          |
# |    actor_loss      | -8.75    |
# |    critic_loss     | 0.0385   |
# |    ent_coef        | 0.0102   |
# |    ent_coef_loss   | -7       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16175    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.7     |
# |    ep_rew_mean     | -3.8     |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 63       |
# |    time_elapsed    | 258      |
# |    total_timesteps | 16378    |
# | train/             |          |
# |    actor_loss      | -8.69    |
# |    critic_loss     | 0.244    |
# |    ent_coef        | 0.00993  |
# |    ent_coef_loss   | -6.76    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16277    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.2     |
# |    ep_rew_mean     | -3.73    |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 63       |
# |    time_elapsed    | 260      |
# |    total_timesteps | 16480    |
# | train/             |          |
# |    actor_loss      | -8.82    |
# |    critic_loss     | 0.0968   |
# |    ent_coef        | 0.00968  |
# |    ent_coef_loss   | -8.11    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16379    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.7     |
# |    ep_rew_mean     | -3.78    |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 412      |
# |    fps             | 63       |
# |    time_elapsed    | 263      |
# |    total_timesteps | 16680    |
# | train/             |          |
# |    actor_loss      | -8.7     |
# |    critic_loss     | 0.034    |
# |    ent_coef        | 0.00921  |
# |    ent_coef_loss   | -8.05    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16579    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.7     |
# |    ep_rew_mean     | -3.7     |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 416      |
# |    fps             | 63       |
# |    time_elapsed    | 266      |
# |    total_timesteps | 16880    |
# | train/             |          |
# |    actor_loss      | -8.16    |
# |    critic_loss     | 0.0714   |
# |    ent_coef        | 0.0088   |
# |    ent_coef_loss   | -5.05    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16779    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.2     |
# |    ep_rew_mean     | -3.76    |
# |    success_rate    | 0.16     |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 63       |
# |    time_elapsed    | 269      |
# |    total_timesteps | 17080    |
# | train/             |          |
# |    actor_loss      | -8.41    |
# |    critic_loss     | 0.203    |
# |    ent_coef        | 0.00837  |
# |    ent_coef_loss   | -6.55    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16979    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.6     |
# |    ep_rew_mean     | -3.8     |
# |    success_rate    | 0.15     |
# | time/              |          |
# |    episodes        | 424      |
# |    fps             | 63       |
# |    time_elapsed    | 273      |
# |    total_timesteps | 17280    |
# | train/             |          |
# |    actor_loss      | -8       |
# |    critic_loss     | 0.0425   |
# |    ent_coef        | 0.008    |
# |    ent_coef_loss   | -6.29    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17179    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.2     |
# |    ep_rew_mean     | -3.75    |
# |    success_rate    | 0.16     |
# | time/              |          |
# |    episodes        | 428      |
# |    fps             | 63       |
# |    time_elapsed    | 274      |
# |    total_timesteps | 17382    |
# | train/             |          |
# |    actor_loss      | -8.2     |
# |    critic_loss     | 0.0914   |
# |    ent_coef        | 0.00782  |
# |    ent_coef_loss   | -6.76    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17281    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.7     |
# |    ep_rew_mean     | -3.63    |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 432      |
# |    fps             | 63       |
# |    time_elapsed    | 275      |
# |    total_timesteps | 17435    |
# | train/             |          |
# |    actor_loss      | -8.18    |
# |    critic_loss     | 0.0512   |
# |    ent_coef        | 0.00773  |
# |    ent_coef_loss   | -6.97    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17334    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.7     |
# |    ep_rew_mean     | -3.6     |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 436      |
# |    fps             | 63       |
# |    time_elapsed    | 278      |
# |    total_timesteps | 17635    |
# | train/             |          |
# |    actor_loss      | -7.73    |
# |    critic_loss     | 0.0793   |
# |    ent_coef        | 0.00741  |
# ...
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.9     |
# |    ep_rew_mean     | -1.97    |
# |    success_rate    | 0.62     |
# | time/              |          |
# |    episodes        | 14464    |
# |    fps             | 63       |
# |    time_elapsed    | 7857     |
# |    total_timesteps | 498111   |
# | train/             |          |
# |    actor_loss      | 5.97     |
# |    critic_loss     | 0.0369   |
# |    ent_coef        | 0.00351  |
# |    ent_coef_loss   | -1.68    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 498010   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -2.07    |
# |    success_rate    | 0.59     |
# | time/              |          |
# |    episodes        | 14468    |
# |    fps             | 63       |
# |    time_elapsed    | 7859     |
# |    total_timesteps | 498262   |
# | train/             |          |
# |    actor_loss      | 6.53     |
# |    critic_loss     | 0.0607   |
# |    ent_coef        | 0.00348  |
# |    ent_coef_loss   | -1.26    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 498161   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.9     |
# |    ep_rew_mean     | -1.95    |
# |    success_rate    | 0.62     |
# | time/              |          |
# |    episodes        | 14472    |
# |    fps             | 63       |
# |    time_elapsed    | 7860     |
# |    total_timesteps | 498308   |
# | train/             |          |
# |    actor_loss      | 6.32     |
# |    critic_loss     | 0.151    |
# |    ent_coef        | 0.00349  |
# |    ent_coef_loss   | 1.22     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 498207   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | -1.92    |
# |    success_rate    | 0.63     |
# | time/              |          |
# |    episodes        | 14476    |
# |    fps             | 63       |
# |    time_elapsed    | 7860     |
# |    total_timesteps | 498336   |
# | train/             |          |
# |    actor_loss      | 6.57     |
# |    critic_loss     | 0.126    |
# |    ent_coef        | 0.00351  |
# |    ent_coef_loss   | 0.381    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 498235   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | -1.82    |
# |    success_rate    | 0.66     |
# | time/              |          |
# |    episodes        | 14480    |
# |    fps             | 63       |
# |    time_elapsed    | 7860     |
# |    total_timesteps | 498361   |
# | train/             |          |
# |    actor_loss      | 5.89     |
# |    critic_loss     | 0.108    |
# |    ent_coef        | 0.00354  |
# |    ent_coef_loss   | 1.35     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 498260   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.7     |
# |    ep_rew_mean     | -1.78    |
# |    success_rate    | 0.67     |
# | time/              |          |
# |    episodes        | 14484    |
# |    fps             | 63       |
# |    time_elapsed    | 7862     |
# |    total_timesteps | 498470   |
# | train/             |          |
# |    actor_loss      | 6.13     |
# |    critic_loss     | 0.467    |
# |    ent_coef        | 0.0036   |
# |    ent_coef_loss   | 0.546    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 498369   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.7     |
# |    ep_rew_mean     | -1.8     |
# |    success_rate    | 0.67     |
# | time/              |          |
# |    episodes        | 14488    |
# |    fps             | 63       |
# |    time_elapsed    | 7864     |
# |    total_timesteps | 498579   |
# | train/             |          |
# |    actor_loss      | 6.17     |
# |    critic_loss     | 0.179    |
# |    ent_coef        | 0.00362  |
# |    ent_coef_loss   | 0.456    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 498478   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | -1.75    |
# |    success_rate    | 0.68     |
# | time/              |          |
# |    episodes        | 14492    |
# |    fps             | 63       |
# |    time_elapsed    | 7864     |
# |    total_timesteps | 498594   |
# | train/             |          |
# |    actor_loss      | 5.98     |
# |    critic_loss     | 0.189    |
# |    ent_coef        | 0.00363  |
# |    ent_coef_loss   | 1.22     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 498493   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | -1.78    |
# |    success_rate    | 0.68     |
# | time/              |          |
# |    episodes        | 14496    |
# |    fps             | 63       |
# |    time_elapsed    | 7866     |
# |    total_timesteps | 498687   |
# | train/             |          |
# |    actor_loss      | 5.89     |
# |    critic_loss     | 0.0771   |
# |    ent_coef        | 0.0036   |
# |    ent_coef_loss   | -0.677   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 498586   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | -1.88    |
# |    success_rate    | 0.67     |
# | time/              |          |
# |    episodes        | 14500    |
# |    fps             | 63       |
# |    time_elapsed    | 7868     |
# |    total_timesteps | 498804   |
# | train/             |          |
# |    actor_loss      | 6.01     |
# |    critic_loss     | 0.0498   |
# |    ent_coef        | 0.00362  |
# |    ent_coef_loss   | -0.671   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 498703   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.3     |
# |    ep_rew_mean     | -1.95    |
# |    success_rate    | 0.66     |
# | time/              |          |
# |    episodes        | 14504    |
# |    fps             | 63       |
# |    time_elapsed    | 7869     |
# |    total_timesteps | 498906   |
# | train/             |          |
# |    actor_loss      | 6.71     |
# |    critic_loss     | 0.348    |
# |    ent_coef        | 0.00366  |
# |    ent_coef_loss   | 0.4      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 498805   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.8     |
# |    ep_rew_mean     | -1.92    |
# |    success_rate    | 0.67     |
# | time/              |          |
# |    episodes        | 14508    |
# |    fps             | 63       |
# |    time_elapsed    | 7870     |
# |    total_timesteps | 498937   |
# | train/             |          |
# |    actor_loss      | 5.9      |
# |    critic_loss     | 0.0689   |
# |    ent_coef        | 0.00368  |
# |    ent_coef_loss   | 0.9      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 498836   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -1.88    |
# |    success_rate    | 0.68     |
# | time/              |          |
# |    episodes        | 14512    |
# |    fps             | 63       |
# |    time_elapsed    | 7871     |
# |    total_timesteps | 499025   |
# | train/             |          |
# |    actor_loss      | 5.99     |
# |    critic_loss     | 0.0701   |
# |    ent_coef        | 0.00369  |
# |    ent_coef_loss   | -0.21    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 498924   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | -1.81    |
# |    success_rate    | 0.7      |
# | time/              |          |
# |    episodes        | 14516    |
# |    fps             | 63       |
# |    time_elapsed    | 7873     |
# |    total_timesteps | 499113   |
# | train/             |          |
# |    actor_loss      | 6.38     |
# |    critic_loss     | 0.127    |
# |    ent_coef        | 0.00375  |
# |    ent_coef_loss   | -1.26    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499012   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | -1.82    |
# |    success_rate    | 0.7      |
# | time/              |          |
# |    episodes        | 14520    |
# |    fps             | 63       |
# |    time_elapsed    | 7873     |
# |    total_timesteps | 499172   |
# | train/             |          |
# |    actor_loss      | 6.2      |
# |    critic_loss     | 0.0649   |
# |    ent_coef        | 0.00376  |
# |    ent_coef_loss   | -1.63    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499071   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.7     |
# |    ep_rew_mean     | -1.77    |
# |    success_rate    | 0.71     |
# | time/              |          |
# |    episodes        | 14524    |
# |    fps             | 63       |
# |    time_elapsed    | 7874     |
# |    total_timesteps | 499228   |
# | train/             |          |
# |    actor_loss      | 6.2      |
# |    critic_loss     | 0.257    |
# |    ent_coef        | 0.00379  |
# |    ent_coef_loss   | 1.62     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499127   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -1.75    |
# |    success_rate    | 0.72     |
# | time/              |          |
# |    episodes        | 14528    |
# |    fps             | 63       |
# |    time_elapsed    | 7875     |
# |    total_timesteps | 499260   |
# | train/             |          |
# |    actor_loss      | 5.89     |
# |    critic_loss     | 0.13     |
# |    ent_coef        | 0.00382  |
# |    ent_coef_loss   | 1.12     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499159   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | -1.73    |
# |    success_rate    | 0.73     |
# | time/              |          |
# |    episodes        | 14532    |
# |    fps             | 63       |
# |    time_elapsed    | 7875     |
# |    total_timesteps | 499292   |
# | train/             |          |
# |    actor_loss      | 6.49     |
# |    critic_loss     | 0.146    |
# |    ent_coef        | 0.0038   |
# |    ent_coef_loss   | -0.278   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499191   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.5     |
# |    ep_rew_mean     | -1.77    |
# |    success_rate    | 0.72     |
# | time/              |          |
# |    episodes        | 14536    |
# |    fps             | 63       |
# |    time_elapsed    | 7877     |
# |    total_timesteps | 499406   |
# | train/             |          |
# |    actor_loss      | 6.32     |
# |    critic_loss     | 0.293    |
# |    ent_coef        | 0.00381  |
# |    ent_coef_loss   | -0.546   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499305   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -1.78    |
# |    success_rate    | 0.72     |
# | time/              |          |
# |    episodes        | 14540    |
# |    fps             | 63       |
# |    time_elapsed    | 7878     |
# |    total_timesteps | 499479   |
# | train/             |          |
# |    actor_loss      | 6.45     |
# |    critic_loss     | 0.0681   |
# |    ent_coef        | 0.00382  |
# |    ent_coef_loss   | -1.46    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499378   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.6     |
# |    ep_rew_mean     | -1.68    |
# |    success_rate    | 0.74     |
# | time/              |          |
# |    episodes        | 14544    |
# |    fps             | 63       |
# |    time_elapsed    | 7880     |
# |    total_timesteps | 499590   |
# | train/             |          |
# |    actor_loss      | 6.22     |
# |    critic_loss     | 0.158    |
# |    ent_coef        | 0.00379  |
# |    ent_coef_loss   | -1.82    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499489   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | -1.69    |
# |    success_rate    | 0.73     |
# | time/              |          |
# |    episodes        | 14548    |
# |    fps             | 63       |
# |    time_elapsed    | 7882     |
# |    total_timesteps | 499709   |
# | train/             |          |
# |    actor_loss      | 6.06     |
# |    critic_loss     | 0.0482   |
# |    ent_coef        | 0.00373  |
# |    ent_coef_loss   | -0.802   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499608   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.5     |
# |    ep_rew_mean     | -1.64    |
# |    success_rate    | 0.74     |
# | time/              |          |
# |    episodes        | 14552    |
# |    fps             | 63       |
# |    time_elapsed    | 7882     |
# |    total_timesteps | 499739   |
# | train/             |          |
# |    actor_loss      | 5.93     |
# |    critic_loss     | 0.079    |
# |    ent_coef        | 0.00371  |
# |    ent_coef_loss   | 0.397    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499638   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.2     |
# |    ep_rew_mean     | -1.66    |
# |    success_rate    | 0.75     |
# | time/              |          |
# |    episodes        | 14556    |
# |    fps             | 63       |
# |    time_elapsed    | 7883     |
# |    total_timesteps | 499818   |
# | train/             |          |
# |    actor_loss      | 6.02     |
# |    critic_loss     | 0.111    |
# |    ent_coef        | 0.00371  |
# |    ent_coef_loss   | -0.319   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499717   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.1     |
# |    ep_rew_mean     | -1.68    |
# |    success_rate    | 0.75     |
# | time/              |          |
# |    episodes        | 14560    |
# |    fps             | 63       |
# |    time_elapsed    | 7885     |
# |    total_timesteps | 499935   |
# | train/             |          |
# |    actor_loss      | 6.18     |
# |    critic_loss     | 0.057    |
# |    ent_coef        | 0.00363  |
# |    ent_coef_loss   | -1.82    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499834   |
# ---------------------------------
# Eval num_timesteps=500000, episode_reward=-1.37 +/- 1.62
# Episode length: 17.70 +/- 19.42
# Success rate: 75.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 17.7     |
# |    mean_reward     | -1.37    |
# |    success_rate    | 0.75     |
# | time/              |          |
# |    total_timesteps | 500000   |
# | train/             |          |
# |    actor_loss      | 5.98     |
# |    critic_loss     | 0.0466   |
# |    ent_coef        | 0.00362  |
# |    ent_coef_loss   | 0.0818   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499899   |
# ---------------------------------
# New best mean reward!

# %% [markdown]
# **Curva di apprendimento SAC**

# %%
# Carica i dati dell'EvalCallback
data = np.load("/content/drive/MyDrive/FAIML-RL-26/evalcallback/sac_source/evaluations.npz")

timesteps = data['timesteps']
mean_rewards = data['results'].mean(axis=1)
success_rates = data['successes'].mean(axis=1)

# Grafico
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

ax1.plot(timesteps, mean_rewards, color='#534AB7', linewidth=2)
ax1.set_xlabel('Timesteps')
ax1.set_ylabel('Mean reward')
ax1.set_title('SAC - source - Mean Reward')
ax1.grid(True, alpha=0.3)

ax2.plot(timesteps, success_rates, color='#0F6E56', linewidth=2)
ax2.set_xlabel('Timesteps')
ax2.set_ylabel('Success rate')
ax2.set_title('SAC - source - Success Rate')
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig("/content/drive/MyDrive/FAIML-RL-26/results/sac_source/learning_curve.png", dpi=150)
plt.show()

# %% [markdown]
# **Main PPO**

# %%
def main() -> None:
    #args = parse_args()

    env = gym.make(
        "PandaPush-v3",
        render_mode="rgb_array",
        type="source",
        reward_type="dense",
    )

    # Ambiente di valutazione SEPARATO (obbligatorio per EvalCallback)
    eval_env = gym.make(
        "PandaPush-v3",
        render_mode="rgb_array",
        type="source",
        reward_type="dense",
    )

    checkpoint_callback = CheckpointCallback(
      save_freq=50000,
      save_path="/content/drive/MyDrive/FAIML-RL-26/checkpoints/",
      name_prefix="ppo_source",
    )

    # Valuta ogni 50k timesteps e salva il modello migliore
    eval_callback = EvalCallback(
        eval_env,
        best_model_save_path=f"/content/drive/MyDrive/FAIML-RL-26/evalcallback/ppo_source/",
        log_path=f"/content/drive/MyDrive/FAIML-RL-26/evalcallback/ppo_source/",
        eval_freq=50000,
        n_eval_episodes=20,
        deterministic=True,
        verbose=1,
    )

    #TODO: add randomization wrapper here
    #TODO: create model and train it
    model = PPO("MultiInputPolicy", env, verbose=1, seed=42, device="cuda")
    model.learn(total_timesteps=500000, callback=CallbackList([checkpoint_callback, eval_callback]))
    save_name = f"ppo_push_none_source_500000"
    # TODO: model.save(save_name)
    model.save(f"/content/drive/MyDrive/FAIML-RL-26/results/ppo_source/{save_name}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Output streaming troncato alle ultime 5000 righe.
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.2        |
# |    ep_rew_mean          | -3.49       |
# |    success_rate         | 0.2         |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 277         |
# |    time_elapsed         | 2508        |
# |    total_timesteps      | 567296      |
# | train/                  |             |
# |    approx_kl            | 0.010033057 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.854      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00901    |
# |    n_updates            | 2760        |
# |    policy_gradient_loss | -0.00358    |
# |    std                  | 0.331       |
# |    value_loss           | 0.00793     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.7        |
# |    ep_rew_mean          | -3.59       |
# |    success_rate         | 0.19        |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 278         |
# |    time_elapsed         | 2518        |
# |    total_timesteps      | 569344      |
# | train/                  |             |
# |    approx_kl            | 0.012785111 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.859      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0186      |
# |    n_updates            | 2770        |
# |    policy_gradient_loss | -0.00261    |
# |    std                  | 0.333       |
# |    value_loss           | 0.012       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.7        |
# |    ep_rew_mean          | -3.38       |
# |    success_rate         | 0.23        |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 279         |
# |    time_elapsed         | 2526        |
# |    total_timesteps      | 571392      |
# | train/                  |             |
# |    approx_kl            | 0.013349795 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.86       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00848     |
# |    n_updates            | 2780        |
# |    policy_gradient_loss | -0.004      |
# |    std                  | 0.331       |
# |    value_loss           | 0.00916     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.3        |
# |    ep_rew_mean          | -3.32       |
# |    success_rate         | 0.26        |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 280         |
# |    time_elapsed         | 2535        |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.013187361 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.857      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0255     |
# |    n_updates            | 2790        |
# |    policy_gradient_loss | -0.000851   |
# |    std                  | 0.331       |
# |    value_loss           | 0.00908     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.7        |
# |    ep_rew_mean          | -3.35       |
# |    success_rate         | 0.23        |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 281         |
# |    time_elapsed         | 2545        |
# |    total_timesteps      | 575488      |
# | train/                  |             |
# |    approx_kl            | 0.016537987 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.847      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0223      |
# |    n_updates            | 2800        |
# |    policy_gradient_loss | -0.00259    |
# |    std                  | 0.329       |
# |    value_loss           | 0.0104      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.7        |
# |    ep_rew_mean          | -3.52       |
# |    success_rate         | 0.19        |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 282         |
# |    time_elapsed         | 2553        |
# |    total_timesteps      | 577536      |
# | train/                  |             |
# |    approx_kl            | 0.015321089 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.823      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000741   |
# |    n_updates            | 2810        |
# |    policy_gradient_loss | -0.00481    |
# |    std                  | 0.324       |
# |    value_loss           | 0.00998     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.7        |
# |    ep_rew_mean          | -3.66       |
# |    success_rate         | 0.17        |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 283         |
# |    time_elapsed         | 2562        |
# |    total_timesteps      | 579584      |
# | train/                  |             |
# |    approx_kl            | 0.012278033 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.802      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00293    |
# |    n_updates            | 2820        |
# |    policy_gradient_loss | -0.00373    |
# |    std                  | 0.324       |
# |    value_loss           | 0.00744     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.7        |
# |    ep_rew_mean          | -3.36       |
# |    success_rate         | 0.23        |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 284         |
# |    time_elapsed         | 2572        |
# |    total_timesteps      | 581632      |
# | train/                  |             |
# |    approx_kl            | 0.010841336 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.808      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00729    |
# |    n_updates            | 2830        |
# |    policy_gradient_loss | -0.00292    |
# |    std                  | 0.326       |
# |    value_loss           | 0.0086      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.2        |
# |    ep_rew_mean          | -3.33       |
# |    success_rate         | 0.24        |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 285         |
# |    time_elapsed         | 2580        |
# |    total_timesteps      | 583680      |
# | train/                  |             |
# |    approx_kl            | 0.012502111 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.809      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00754     |
# |    n_updates            | 2840        |
# |    policy_gradient_loss | -0.00246    |
# |    std                  | 0.324       |
# |    value_loss           | 0.0123      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.8        |
# |    ep_rew_mean          | -3.15       |
# |    success_rate         | 0.27        |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 286         |
# |    time_elapsed         | 2590        |
# |    total_timesteps      | 585728      |
# | train/                  |             |
# |    approx_kl            | 0.009801998 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.788      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00543    |
# |    n_updates            | 2850        |
# |    policy_gradient_loss | -0.00154    |
# |    std                  | 0.321       |
# |    value_loss           | 0.0107      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.8        |
# |    ep_rew_mean          | -3.12       |
# |    success_rate         | 0.25        |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 287         |
# |    time_elapsed         | 2599        |
# |    total_timesteps      | 587776      |
# | train/                  |             |
# |    approx_kl            | 0.013587402 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.745      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0518      |
# |    n_updates            | 2860        |
# |    policy_gradient_loss | -0.00298    |
# |    std                  | 0.316       |
# |    value_loss           | 0.016       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.7        |
# |    ep_rew_mean          | -3.64       |
# |    success_rate         | 0.17        |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 288         |
# |    time_elapsed         | 2608        |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.011622396 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.723      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0283      |
# |    n_updates            | 2870        |
# |    policy_gradient_loss | 9.23e-05    |
# |    std                  | 0.316       |
# |    value_loss           | 0.00763     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.7        |
# |    ep_rew_mean          | -3.37       |
# |    success_rate         | 0.23        |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 289         |
# |    time_elapsed         | 2618        |
# |    total_timesteps      | 591872      |
# | train/                  |             |
# |    approx_kl            | 0.013980868 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.723      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00144    |
# |    n_updates            | 2880        |
# |    policy_gradient_loss | -0.00378    |
# |    std                  | 0.315       |
# |    value_loss           | 0.00792     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.3        |
# |    ep_rew_mean          | -3.07       |
# |    success_rate         | 0.3         |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 290         |
# |    time_elapsed         | 2627        |
# |    total_timesteps      | 593920      |
# | train/                  |             |
# |    approx_kl            | 0.009891992 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.73       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0204     |
# |    n_updates            | 2890        |
# |    policy_gradient_loss | -0.00655    |
# |    std                  | 0.318       |
# |    value_loss           | 0.0102      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.8        |
# |    ep_rew_mean          | -3.29       |
# |    success_rate         | 0.25        |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 291         |
# |    time_elapsed         | 2635        |
# |    total_timesteps      | 595968      |
# | train/                  |             |
# |    approx_kl            | 0.011892339 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.751      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00129    |
# |    n_updates            | 2900        |
# |    policy_gradient_loss | -0.000999   |
# |    std                  | 0.318       |
# |    value_loss           | 0.0168      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.2        |
# |    ep_rew_mean          | -3.64       |
# |    success_rate         | 0.16        |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 292         |
# |    time_elapsed         | 2645        |
# |    total_timesteps      | 598016      |
# | train/                  |             |
# |    approx_kl            | 0.015117994 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.735      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00499     |
# |    n_updates            | 2910        |
# |    policy_gradient_loss | -0.0019     |
# |    std                  | 0.314       |
# |    value_loss           | 0.0103      |
# -----------------------------------------
# Eval num_timesteps=600000, episode_reward=-2.88 +/- 2.03
# Episode length: 35.30 +/- 22.45
# Success rate: 30.00%
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 35.3        |
# |    mean_reward          | -2.88       |
# |    success_rate         | 0.3         |
# | time/                   |             |
# |    total_timesteps      | 600000      |
# | train/                  |             |
# |    approx_kl            | 0.015410826 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.705      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00604    |
# |    n_updates            | 2920        |
# |    policy_gradient_loss | -0.0066     |
# |    std                  | 0.312       |
# |    value_loss           | 0.0112      |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.2     |
# |    ep_rew_mean     | -3.61    |
# |    success_rate    | 0.16     |
# | time/              |          |
# |    fps             | 225      |
# |    iterations      | 293      |
# |    time_elapsed    | 2657     |
# |    total_timesteps | 600064   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.7        |
# |    ep_rew_mean          | -3.47       |
# |    success_rate         | 0.19        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 294         |
# |    time_elapsed         | 2665        |
# |    total_timesteps      | 602112      |
# | train/                  |             |
# |    approx_kl            | 0.011889314 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.675      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000406    |
# |    n_updates            | 2930        |
# |    policy_gradient_loss | -0.00615    |
# |    std                  | 0.308       |
# |    value_loss           | 0.00954     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.2        |
# |    ep_rew_mean          | -3.36       |
# |    success_rate         | 0.22        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 295         |
# |    time_elapsed         | 2675        |
# |    total_timesteps      | 604160      |
# | train/                  |             |
# |    approx_kl            | 0.013061803 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.651      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00782     |
# |    n_updates            | 2940        |
# |    policy_gradient_loss | -0.00341    |
# |    std                  | 0.307       |
# |    value_loss           | 0.00747     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.7        |
# |    ep_rew_mean          | -3.44       |
# |    success_rate         | 0.23        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 296         |
# |    time_elapsed         | 2685        |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.011586262 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.633      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0206     |
# |    n_updates            | 2950        |
# |    policy_gradient_loss | -0.00559    |
# |    std                  | 0.304       |
# |    value_loss           | 0.0118      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.2        |
# |    ep_rew_mean          | -3.44       |
# |    success_rate         | 0.2         |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 297         |
# |    time_elapsed         | 2693        |
# |    total_timesteps      | 608256      |
# | train/                  |             |
# |    approx_kl            | 0.011786718 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.603      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0288     |
# |    n_updates            | 2960        |
# |    policy_gradient_loss | -0.00254    |
# |    std                  | 0.3         |
# |    value_loss           | 0.0124      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 38.7         |
# |    ep_rew_mean          | -3.3         |
# |    success_rate         | 0.23         |
# | time/                   |              |
# |    fps                  | 225          |
# |    iterations           | 298          |
# |    time_elapsed         | 2703         |
# |    total_timesteps      | 610304       |
# | train/                  |              |
# |    approx_kl            | 0.0111342445 |
# |    clip_fraction        | 0.166        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.597       |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0155      |
# |    n_updates            | 2970         |
# |    policy_gradient_loss | -0.00112     |
# |    std                  | 0.303        |
# |    value_loss           | 0.00649      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.2        |
# |    ep_rew_mean          | -3.55       |
# |    success_rate         | 0.2         |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 299         |
# |    time_elapsed         | 2712        |
# |    total_timesteps      | 612352      |
# | train/                  |             |
# |    approx_kl            | 0.014706049 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.585      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0255     |
# |    n_updates            | 2980        |
# |    policy_gradient_loss | -0.00466    |
# |    std                  | 0.299       |
# |    value_loss           | 0.0122      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 40.7         |
# |    ep_rew_mean          | -3.45        |
# |    success_rate         | 0.19         |
# | time/                   |              |
# |    fps                  | 225          |
# |    iterations           | 300          |
# |    time_elapsed         | 2721         |
# |    total_timesteps      | 614400       |
# | train/                  |              |
# |    approx_kl            | 0.0113763455 |
# |    clip_fraction        | 0.14         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.575       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.012       |
# |    n_updates            | 2990         |
# |    policy_gradient_loss | 0.000732     |
# |    std                  | 0.301        |
# |    value_loss           | 0.00567      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.7        |
# |    ep_rew_mean          | -3.45       |
# |    success_rate         | 0.21        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 301         |
# |    time_elapsed         | 2730        |
# |    total_timesteps      | 616448      |
# | train/                  |             |
# |    approx_kl            | 0.013172365 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.593      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00328    |
# |    n_updates            | 3000        |
# |    policy_gradient_loss | -0.00201    |
# |    std                  | 0.302       |
# |    value_loss           | 0.00693     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 39.7       |
# |    ep_rew_mean          | -3.6       |
# |    success_rate         | 0.21       |
# | time/                   |            |
# |    fps                  | 225        |
# |    iterations           | 302        |
# |    time_elapsed         | 2739       |
# |    total_timesteps      | 618496     |
# | train/                  |            |
# |    approx_kl            | 0.00926326 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.614     |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00455    |
# |    n_updates            | 3010       |
# |    policy_gradient_loss | -0.00239   |
# |    std                  | 0.304      |
# |    value_loss           | 0.0181     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.7        |
# |    ep_rew_mean          | -3.62       |
# |    success_rate         | 0.19        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 303         |
# |    time_elapsed         | 2748        |
# |    total_timesteps      | 620544      |
# | train/                  |             |
# |    approx_kl            | 0.011664644 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.632      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0284     |
# |    n_updates            | 3020        |
# |    policy_gradient_loss | -0.0046     |
# |    std                  | 0.306       |
# |    value_loss           | 0.00893     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.2        |
# |    ep_rew_mean          | -3.69       |
# |    success_rate         | 0.16        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 304         |
# |    time_elapsed         | 2758        |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.010269256 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.632      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0114      |
# |    n_updates            | 3030        |
# |    policy_gradient_loss | -0.00118    |
# |    std                  | 0.306       |
# |    value_loss           | 0.0093      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.7        |
# |    ep_rew_mean          | -3.61       |
# |    success_rate         | 0.17        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 305         |
# |    time_elapsed         | 2766        |
# |    total_timesteps      | 624640      |
# | train/                  |             |
# |    approx_kl            | 0.014488941 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.635      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00313     |
# |    n_updates            | 3040        |
# |    policy_gradient_loss | -0.00532    |
# |    std                  | 0.306       |
# |    value_loss           | 0.00841     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.2        |
# |    ep_rew_mean          | -3.43       |
# |    success_rate         | 0.18        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 306         |
# |    time_elapsed         | 2775        |
# |    total_timesteps      | 626688      |
# | train/                  |             |
# |    approx_kl            | 0.013881771 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.648      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0155     |
# |    n_updates            | 3050        |
# |    policy_gradient_loss | -0.00576    |
# |    std                  | 0.308       |
# |    value_loss           | 0.00781     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.2        |
# |    ep_rew_mean          | -3.42       |
# |    success_rate         | 0.2         |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 307         |
# |    time_elapsed         | 2785        |
# |    total_timesteps      | 628736      |
# | train/                  |             |
# |    approx_kl            | 0.015884928 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.649      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00809    |
# |    n_updates            | 3060        |
# |    policy_gradient_loss | -0.00124    |
# |    std                  | 0.306       |
# |    value_loss           | 0.0123      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.7        |
# |    ep_rew_mean          | -3.44       |
# |    success_rate         | 0.23        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 308         |
# |    time_elapsed         | 2793        |
# |    total_timesteps      | 630784      |
# | train/                  |             |
# |    approx_kl            | 0.014337501 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.643      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000356    |
# |    n_updates            | 3070        |
# |    policy_gradient_loss | -0.00102    |
# |    std                  | 0.307       |
# |    value_loss           | 0.00833     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.7        |
# |    ep_rew_mean          | -3.51       |
# |    success_rate         | 0.21        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 309         |
# |    time_elapsed         | 2803        |
# |    total_timesteps      | 632832      |
# | train/                  |             |
# |    approx_kl            | 0.011964009 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.619      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000406   |
# |    n_updates            | 3080        |
# |    policy_gradient_loss | -0.000489   |
# |    std                  | 0.303       |
# |    value_loss           | 0.0113      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.6        |
# |    ep_rew_mean          | -3.73       |
# |    success_rate         | 0.13        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 310         |
# |    time_elapsed         | 2812        |
# |    total_timesteps      | 634880      |
# | train/                  |             |
# |    approx_kl            | 0.012650657 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.609      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00933    |
# |    n_updates            | 3090        |
# |    policy_gradient_loss | -0.00201    |
# |    std                  | 0.304       |
# |    value_loss           | 0.0086      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.7        |
# |    ep_rew_mean          | -3.51       |
# |    success_rate         | 0.19        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 311         |
# |    time_elapsed         | 2820        |
# |    total_timesteps      | 636928      |
# | train/                  |             |
# |    approx_kl            | 0.013707526 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.609      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00894    |
# |    n_updates            | 3100        |
# |    policy_gradient_loss | -0.00531    |
# |    std                  | 0.303       |
# |    value_loss           | 0.0045      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.7        |
# |    ep_rew_mean          | -3.31       |
# |    success_rate         | 0.23        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 312         |
# |    time_elapsed         | 2830        |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.014221389 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.608      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00383    |
# |    n_updates            | 3110        |
# |    policy_gradient_loss | -0.0034     |
# |    std                  | 0.304       |
# |    value_loss           | 0.0121      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.7        |
# |    ep_rew_mean          | -3.46       |
# |    success_rate         | 0.21        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 313         |
# |    time_elapsed         | 2838        |
# |    total_timesteps      | 641024      |
# | train/                  |             |
# |    approx_kl            | 0.010490388 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.621      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00464     |
# |    n_updates            | 3120        |
# |    policy_gradient_loss | -0.00358    |
# |    std                  | 0.306       |
# |    value_loss           | 0.0123      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.2        |
# |    ep_rew_mean          | -3.56       |
# |    success_rate         | 0.18        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 314         |
# |    time_elapsed         | 2847        |
# |    total_timesteps      | 643072      |
# | train/                  |             |
# |    approx_kl            | 0.012106763 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.643      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0289     |
# |    n_updates            | 3130        |
# |    policy_gradient_loss | 0.000585    |
# |    std                  | 0.308       |
# |    value_loss           | 0.00844     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.2        |
# |    ep_rew_mean          | -3.71       |
# |    success_rate         | 0.16        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 315         |
# |    time_elapsed         | 2857        |
# |    total_timesteps      | 645120      |
# | train/                  |             |
# |    approx_kl            | 0.010696074 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.645      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00737    |
# |    n_updates            | 3140        |
# |    policy_gradient_loss | -0.000845   |
# |    std                  | 0.307       |
# |    value_loss           | 0.00621     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.7        |
# |    ep_rew_mean          | -3.42       |
# |    success_rate         | 0.23        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 316         |
# |    time_elapsed         | 2865        |
# |    total_timesteps      | 647168      |
# | train/                  |             |
# |    approx_kl            | 0.011329165 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.644      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00452    |
# |    n_updates            | 3150        |
# |    policy_gradient_loss | -0.00315    |
# |    std                  | 0.307       |
# |    value_loss           | 0.00452     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.2        |
# |    ep_rew_mean          | -3.27       |
# |    success_rate         | 0.22        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 317         |
# |    time_elapsed         | 2874        |
# |    total_timesteps      | 649216      |
# | train/                  |             |
# |    approx_kl            | 0.015446622 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.662      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0162      |
# |    n_updates            | 3160        |
# |    policy_gradient_loss | -0.00356    |
# |    std                  | 0.31        |
# |    value_loss           | 0.0165      |
# -----------------------------------------
# Eval num_timesteps=650000, episode_reward=-3.20 +/- 1.69
# Episode length: 40.20 +/- 19.60
# Success rate: 20.00%
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 40.2        |
# |    mean_reward          | -3.2        |
# |    success_rate         | 0.2         |
# | time/                   |             |
# |    total_timesteps      | 650000      |
# | train/                  |             |
# |    approx_kl            | 0.014766234 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.673      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0277      |
# |    n_updates            | 3170        |
# |    policy_gradient_loss | 0.000368    |
# |    std                  | 0.31        |
# |    value_loss           | 0.0122      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.7     |
# |    ep_rew_mean     | -3.29    |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    fps             | 225      |
# |    iterations      | 318      |
# |    time_elapsed    | 2886     |
# |    total_timesteps | 651264   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 40.7       |
# |    ep_rew_mean          | -3.42      |
# |    success_rate         | 0.19       |
# | time/                   |            |
# |    fps                  | 225        |
# |    iterations           | 319        |
# |    time_elapsed         | 2895       |
# |    total_timesteps      | 653312     |
# | train/                  |            |
# |    approx_kl            | 0.01507486 |
# |    clip_fraction        | 0.148      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.677     |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00491    |
# |    n_updates            | 3180       |
# |    policy_gradient_loss | -0.000471  |
# |    std                  | 0.31       |
# |    value_loss           | 0.00707    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.2        |
# |    ep_rew_mean          | -3.48       |
# |    success_rate         | 0.18        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 320         |
# |    time_elapsed         | 2903        |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.010628973 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00919     |
# |    n_updates            | 3190        |
# |    policy_gradient_loss | -0.00145    |
# |    std                  | 0.312       |
# |    value_loss           | 0.00899     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.2        |
# |    ep_rew_mean          | -3.39       |
# |    success_rate         | 0.22        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 321         |
# |    time_elapsed         | 2913        |
# |    total_timesteps      | 657408      |
# | train/                  |             |
# |    approx_kl            | 0.014123604 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.689      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00932     |
# |    n_updates            | 3200        |
# |    policy_gradient_loss | -0.00425    |
# |    std                  | 0.312       |
# |    value_loss           | 0.0137      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.3        |
# |    ep_rew_mean          | -3.29       |
# |    success_rate         | 0.28        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 322         |
# |    time_elapsed         | 2921        |
# |    total_timesteps      | 659456      |
# | train/                  |             |
# |    approx_kl            | 0.013541859 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0138      |
# |    n_updates            | 3210        |
# |    policy_gradient_loss | -0.00215    |
# |    std                  | 0.31        |
# |    value_loss           | 0.0139      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.3        |
# |    ep_rew_mean          | -3.27       |
# |    success_rate         | 0.28        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 323         |
# |    time_elapsed         | 2931        |
# |    total_timesteps      | 661504      |
# | train/                  |             |
# |    approx_kl            | 0.016021617 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0173     |
# |    n_updates            | 3220        |
# |    policy_gradient_loss | -0.00281    |
# |    std                  | 0.308       |
# |    value_loss           | 0.0177      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.7        |
# |    ep_rew_mean          | -3.56       |
# |    success_rate         | 0.17        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 324         |
# |    time_elapsed         | 2940        |
# |    total_timesteps      | 663552      |
# | train/                  |             |
# |    approx_kl            | 0.011654564 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.675      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0165      |
# |    n_updates            | 3230        |
# |    policy_gradient_loss | -0.00601    |
# |    std                  | 0.31        |
# |    value_loss           | 0.0087      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.2        |
# |    ep_rew_mean          | -3.66       |
# |    success_rate         | 0.16        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 325         |
# |    time_elapsed         | 2949        |
# |    total_timesteps      | 665600      |
# | train/                  |             |
# |    approx_kl            | 0.011908855 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.697      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0147      |
# |    n_updates            | 3240        |
# ...
# |    std                  | 0.256       |
# |    value_loss           | 0.00555     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.2        |
# |    ep_rew_mean          | -3.55       |
# |    success_rate         | 0.22        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 474         |
# |    time_elapsed         | 4309        |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.014885288 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.143      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00903    |
# |    n_updates            | 4730        |
# |    policy_gradient_loss | -0.00129    |
# |    std                  | 0.258       |
# |    value_loss           | 0.0066      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.7        |
# |    ep_rew_mean          | -3.54       |
# |    success_rate         | 0.21        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 475         |
# |    time_elapsed         | 4319        |
# |    total_timesteps      | 972800      |
# | train/                  |             |
# |    approx_kl            | 0.017145194 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.155      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0247     |
# |    n_updates            | 4740        |
# |    policy_gradient_loss | -0.00193    |
# |    std                  | 0.259       |
# |    value_loss           | 0.00457     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.7        |
# |    ep_rew_mean          | -3.71       |
# |    success_rate         | 0.17        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 476         |
# |    time_elapsed         | 4329        |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.016232412 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.149      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00779    |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | -0.00125    |
# |    std                  | 0.257       |
# |    value_loss           | 0.00496     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.1        |
# |    ep_rew_mean          | -3.69       |
# |    success_rate         | 0.14        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 477         |
# |    time_elapsed         | 4337        |
# |    total_timesteps      | 976896      |
# | train/                  |             |
# |    approx_kl            | 0.017116996 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.143      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.01        |
# |    n_updates            | 4760        |
# |    policy_gradient_loss | -0.00405    |
# |    std                  | 0.258       |
# |    value_loss           | 0.00652     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.6         |
# |    ep_rew_mean          | -3.62        |
# |    success_rate         | 0.15         |
# | time/                   |              |
# |    fps                  | 225          |
# |    iterations           | 478          |
# |    time_elapsed         | 4346         |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 0.0104964655 |
# |    clip_fraction        | 0.177        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.145       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.015        |
# |    n_updates            | 4770         |
# |    policy_gradient_loss | -0.000204    |
# |    std                  | 0.258        |
# |    value_loss           | 0.00696      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.2        |
# |    ep_rew_mean          | -3.41       |
# |    success_rate         | 0.18        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 479         |
# |    time_elapsed         | 4355        |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.011354014 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.158      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0797      |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | -0.00237    |
# |    std                  | 0.26        |
# |    value_loss           | 0.0102      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.2        |
# |    ep_rew_mean          | -3.42       |
# |    success_rate         | 0.18        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 480         |
# |    time_elapsed         | 4364        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.015112182 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.161      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0221      |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.00599    |
# |    std                  | 0.258       |
# |    value_loss           | 0.00801     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.7        |
# |    ep_rew_mean          | -3.51       |
# |    success_rate         | 0.17        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 481         |
# |    time_elapsed         | 4373        |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.013568822 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.156      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00806     |
# |    n_updates            | 4800        |
# |    policy_gradient_loss | 0.00148     |
# |    std                  | 0.259       |
# |    value_loss           | 0.00699     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.7        |
# |    ep_rew_mean          | -3.45       |
# |    success_rate         | 0.19        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 482         |
# |    time_elapsed         | 4381        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.012536754 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.148      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0218     |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | 2.2e-05     |
# |    std                  | 0.257       |
# |    value_loss           | 0.0082      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.2        |
# |    ep_rew_mean          | -3.74       |
# |    success_rate         | 0.16        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 483         |
# |    time_elapsed         | 4390        |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.014134744 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.109      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0132     |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.00625    |
# |    std                  | 0.254       |
# |    value_loss           | 0.0154      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.1        |
# |    ep_rew_mean          | -3.93       |
# |    success_rate         | 0.12        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 484         |
# |    time_elapsed         | 4400        |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.018679451 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0991     |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0115      |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.00184    |
# |    std                  | 0.255       |
# |    value_loss           | 0.0121      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.1        |
# |    ep_rew_mean          | -3.9        |
# |    success_rate         | 0.12        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 485         |
# |    time_elapsed         | 4408        |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.016148623 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.109      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00339     |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | -0.00921    |
# |    std                  | 0.255       |
# |    value_loss           | 0.00729     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.2        |
# |    ep_rew_mean          | -3.35       |
# |    success_rate         | 0.22        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 486         |
# |    time_elapsed         | 4417        |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.016053587 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.13       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0304      |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | -0.00246    |
# |    std                  | 0.258       |
# |    value_loss           | 0.00287     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.1        |
# |    ep_rew_mean          | -3.33       |
# |    success_rate         | 0.23        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 487         |
# |    time_elapsed         | 4427        |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.015523318 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.149      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00323     |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | -0.00686    |
# |    std                  | 0.259       |
# |    value_loss           | 0.0105      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43          |
# |    ep_rew_mean          | -3.73       |
# |    success_rate         | 0.15        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 488         |
# |    time_elapsed         | 4435        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.015677199 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.142      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0217      |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | -1.56e-05   |
# |    std                  | 0.258       |
# |    value_loss           | 0.0206      |
# -----------------------------------------
# Eval num_timesteps=1000000, episode_reward=-3.10 +/- 1.91
# Episode length: 37.75 +/- 21.22
# Success rate: 25.00%
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 37.8        |
# |    mean_reward          | -3.1        |
# |    success_rate         | 0.25        |
# | time/                   |             |
# |    total_timesteps      | 1000000     |
# | train/                  |             |
# |    approx_kl            | 0.015040077 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.134      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0183     |
# |    n_updates            | 4880        |
# |    policy_gradient_loss | -0.00143    |
# |    std                  | 0.257       |
# |    value_loss           | 0.00341     |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.7     |
# |    ep_rew_mean     | -3.48    |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    fps             | 225      |
# |    iterations      | 489      |
# |    time_elapsed    | 4446     |
# |    total_timesteps | 1001472  |
# ---------------------------------

# %% [markdown]
# **Curva di apprendimento PPO**

# %%
# Carica i dati dell'EvalCallback
data = np.load("/content/drive/MyDrive/FAIML-RL-26/evalcallback/ppo_source/evaluations.npz")

timesteps = data['timesteps']
mean_rewards = data['results'].mean(axis=1)
success_rates = data['successes'].mean(axis=1)

# Grafico
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

ax1.plot(timesteps, mean_rewards, color='#534AB7', linewidth=2)
ax1.set_xlabel('Timesteps')
ax1.set_ylabel('Mean reward')
ax1.set_title('PPO - source - Mean Reward')
ax1.grid(True, alpha=0.3)

ax2.plot(timesteps, success_rates, color='#0F6E56', linewidth=2)
ax2.set_xlabel('Timesteps')
ax2.set_ylabel('Success rate')
ax2.set_title('PPO - source - Success Rate')
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig("/content/drive/MyDrive/FAIML-RL-26/results/ppo_source/learning_curve.png", dpi=150)
plt.show()
